# %% [markdown]
# # Here we provide an example how to run sreality crawler

# %%
# %load_ext autoreload
# %autoreload 2
from f_sreality import *

# %% [markdown]
# ### initialize the class and call auto method

# %%
s = sreality()

# %%
s.auto(store=True, nofrecords= 500)
# Out:
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
#  in iteration number 88, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 89, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 90, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 91, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 92, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 93, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 94, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 95, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 96, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 97, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 98, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 99, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 100, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 101, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 102, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 103, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 104, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 105, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 106, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 107, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 108, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 109, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 110, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 111, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 112, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 113, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 114, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 115, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 116, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 117, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 118, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 119, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 120, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 121, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 122, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 123, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 124, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 125, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 126, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 127, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 128, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 129, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 130, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 131, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 132, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 133, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 134, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 135, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 136, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 137, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 138, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 139, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 140, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 141, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 142, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 143, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 144, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 145, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 146, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 147, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 148, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 149, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 150, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 151, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 152, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 153, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 154, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 155, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 156, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 157, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 158, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 159, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 160, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 161, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 162, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 163, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 164, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 165, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 166, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 167, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 168, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 169, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 170, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 171, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 172, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 173, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 174, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 175, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 176, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 177, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 178, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 179, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 180, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 181, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 182, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 183, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 184, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 185, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 186, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 187, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 188, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 189, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 190, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 191, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 192, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 193, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 194, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 195, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 196, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 197, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 198, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 199, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 200, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 201, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 202, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 203, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 204, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 205, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 206, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 207, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 208, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 209, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 210, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 211, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 212, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 213, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 214, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 215, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 216, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 217, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 218, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 219, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 220, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 221, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 222, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 223, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 224, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 225, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 226, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 227, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 228, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 229, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 230, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 231, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 232, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 233, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 234, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 235, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 236, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 237, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 238, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 239, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 240, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 241, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 242, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 243, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 244, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 245, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 246, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 247, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 248, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 249, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 250, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 251, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 252, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 253, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 254, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 255, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 256, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 257, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 258, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 259, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 260, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 261, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 262, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 263, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 264, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 265, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 266, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 267, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 268, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 269, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 270, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 271, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 272, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 273, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 274, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 275, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 276, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 277, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 278, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 279, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 280, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 281, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 282, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 283, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 284, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 285, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 286, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 287, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 288, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 289, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 290, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 291, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 292, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 293, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 294, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 295, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 296, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 297, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 298, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 299, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 300, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 301, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 302, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 303, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 304, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 305, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 306, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 307, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 308, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 309, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 310, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 311, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 312, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 313, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 314, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 315, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 316, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 317, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 318, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 319, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 320, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 321, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 322, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 323, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 324, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 325, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 326, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 327, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 328, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 329, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 330, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 331, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 332, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 333, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 334, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 335, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 336, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 337, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 338, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 339, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 340, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 341, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 342, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 343, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 344, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 345, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 346, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 347, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 348, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 349, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 350, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 351, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 352, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 353, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 354, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 355, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 356, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 357, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 358, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 359, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 360, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 361, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 362, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 363, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 364, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 365, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 366, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 367, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 368, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 369, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 370, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 371, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 372, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 373, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 374, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 375, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 376, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 377, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 378, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 379, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 380, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 381, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 382, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 383, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 384, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 385, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 386, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 387, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 388, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 389, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 390, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 391, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 392, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 393, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 394, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 395, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 396, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
# ...
#  in iteration number 413, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 414, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 415, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 416, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 417, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 418, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 419, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 420, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 421, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 422, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 423, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 424, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 425, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 426, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 427, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 428, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 429, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 430, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 431, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 432, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 433, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 434, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 435, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 436, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 437, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 438, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 439, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 440, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 441, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 442, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 443, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 444, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 445, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 446, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 447, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 448, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 449, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 450, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 451, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 452, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 453, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 454, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 455, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 456, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 457, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 458, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 459, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 460, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 461, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 462, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 463, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 464, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 465, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 466, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 467, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 468, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 469, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 470, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 471, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 472, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 473, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 474, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 475, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 476, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 477, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 478, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 479, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 480, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 481, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 482, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 483, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 484, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 485, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 486, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 487, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 488, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 489, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 490, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 491, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 492, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 493, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 494, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 495, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 496, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 497, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 498, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#  in iteration number 499, embedded and estates parameters are missing. Skipping this row. If the iteration is less than 997 you should not worry about it.
#
# detailed urls stored.
# HBox(children=(IntProgress(value=0, max=4353), HTML(value='')))
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-3-8f895fb9ac17> in <module>
# ----> 1 s.auto(store=True, nofrecords= 500)
#
# ~/MEGAsync/my_projects/seznam_hackathon/crawler/f_sreality.py in auto(self, store, nofrecords)
#     429
#     430         #get detailed info
# --> 431         self.addDetailedInfoToMaster()
#     432
#     433         #create outpudf
#
# ~/MEGAsync/my_projects/seznam_hackathon/crawler/f_sreality.py in addDetailedInfoToMaster(self)
#     131
#     132                 #scrape this URL
# --> 133                 detailed_result_one = self.detailedInfoFromOne(url_detail_one)
#     134
#     135                 #append it to master df
#
# ~/MEGAsync/my_projects/seznam_hackathon/crawler/f_sreality.py in detailedInfoFromOne(self, url_detail_one)
#     216         call = requests.get(url_detail_one, params=param)
#     217
# --> 218         jsondata = call.json()
#     219
#     220
#
# ~/anaconda3/envs/seznam/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/envs/seznam/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/envs/seznam/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/envs/seznam/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
